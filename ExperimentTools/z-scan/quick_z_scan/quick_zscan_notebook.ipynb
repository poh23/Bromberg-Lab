# %%
from create_graph import main

main()
# Out:
# DataFrame with transmittance values:
#  laser power(A)     Medium  Power before cuvette (mW)  Power after cuvette (mW)  exposure (microsecs)  ND  Image Exists      Image Filename  Transmittance (radius=185)
#             1.1 1:500 blue                    0.00048                   0.00041              1235.833 2.0          True 1-500_blue_1.1A.png                    0.999315
#             1.1        NaN                        NaN                       NaN                   NaN NaN         False                None                         NaN
#             1.1  1:50 blue                    0.00043                   0.00026              1946.277 4.0          True  1-50_blue_1.1A.png                    0.999037
#             1.1  1:100 red                    0.00045                   0.00017              2964.385 5.0         False                None                         NaN
# ...
